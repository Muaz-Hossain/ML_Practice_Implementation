# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# irid dataset import
from sklearn.datasets import load_iris
data = load_iris()
X = pd.DataFrame(data.data, columns=data.feature_names)

#standardize

scaler = StandardScaler()
X_scaled =scaler.fit_transform(X)

# %%
#apply pca
pca = PCA(n_components=2)
X_pca=pca.fit_transform(X_scaled)

# %%
print("Explaned variance ratio:", pca.explained_variance_ratio_)
print("totall variance ratio:", sum(pca.explained_variance_ratio_))
# Out:
# Explaned variance ratio: [0.72962445 0.22850762]
# totall variance ratio: 0.9581320720000166

# %%
plt.scatter(X_pca[:,0], X_pca[:,1],c=data.target, cmap='viridis')
plt.xlabel('pca 1')
plt.ylabel('pca2')
plt.title('pca on iris dataset')
plt.show()
